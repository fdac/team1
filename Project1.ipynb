# %% [markdown]
# #Project 1: Discover BitBucket code repositories
#
# ## Context
# You work for a cloud application provider DeveloperParadise that needs to convince its investors
# that their business has a bright future.
#
# Your task is to show that the number of customers (users of DeveloperParadise, which happens to
# compete with Atlassian's BitBucket) is comparable to that of  BitBucket. The presentation for investors
# is next week (completely incidentally, exactly on the day this project is due).
#
# Feel free to use examples below or any other information you can gather to obtain as complete as possible list of
# users and repositories hosted on BitBucket.
#
# While a template for the search strategy is provided, feel free to use any means (including borrowing with attribution from the other teams) to get as many as you can within this very short but, unfortunately, very realistic time frame.
#
#
# ## Important Notes
#
# Please keep in mind operational data pitfalls, such as
#    * lack of context
#    * missing data
#    * possibly incorrect data
#
# 1. DeveloperParadise may focus on specific types of customers (e.g., size, programming language, or other characteristics), and that number is a subset of all customers.
#  * Pick the desired characteristics of target customers for DeveloperParadise and estimate their percentage is in your retrieved set
# 1. Is there any way to estimate what fraction of all BitBucket customers/repositories are in the retrieved set?
# 1. Is the distribution of different types of customers the same in the retrieved and undiscovered sets of BitBucket customers?

# %% [markdown]
# ### Example 1. Search for a keyword 'test'
#
# * Unfortunately, BitBucket does not have a documented search API
#
# So feel free to experiment with an undocumented search API below that appears to
# yeld some results, though it is not clear how complete they are and
# how exactly the results are provided by BitBucket.  You don't need to
# follow the search strategy outlined below, it is just one of many possible approaches.

# %%
import requests, json, sys, time, re, BeautifulSoup
key = 'python'
URL = 'https://bitbucket.org/repo/all?name=' + key
r = requests .get(URL)
t = r.text
soup = BeautifulSoup.BeautifulSoup(t)
start = 0
npages = 1
for link in soup.findAll('a'):
    print link
    if (start == 3): continue
    s = link.get('href')
    if (start == 0):
        if ('/account/signin/?next' in s):
            start = 1
            continue
        else:
            continue   
    if  s == '#': continue 
        
    # This is the way the remaining pages in the search results are marked
    m = re.search(r'^/repo/all/(\d*)\?', s)
    if  m:
        start = 2
        #get max num
        i = m.group(1)
        if (int(i) > npages): npages = int(i)
        #print npages
    else:
        if start == 2: 
            start = 3
            continue
        # Print the repo urls
        print s
        
#now need to go over the remaining pages        
# from 2 to npages
#np = unicode(npages)
#print '/repo/all/'+ np + '?name=' + key
# Out:
# <a href="/">
# <span class="aui-header-logo-device">Bitbucket</span>
# </a>
# <a href="/features">
#           Features
#         </a>
# <a href="/plans">
#             Pricing
#         </a>
# <a class="aui-dropdown2-trigger" id="help-dropdown-trigger" aria-controls="header-help-dropdown" aria-owns="header-help-dropdown" aria-haspopup="true" data-container="#header .aui-header-inner" href="#header-help-dropdown">
# <span class="aui-icon aui-icon-small aui-iconfont-help">Help</span><span class="aui-icon-dropdown"></span>
# </a>
# <a href="/whats-new" id="features-link">
#                 Latest features
#               </a>
# <a class="support-ga" data-support-gaq-page="DocumentationHome" href="https://confluence.atlassian.com/x/bgozDQ" target="_blank">
#                 Documentation
#               </a>
# <a class="support-ga" data-support-gaq-page="Documentation101" href="https://confluence.atlassian.com/x/cgozDQ" target="_blank">
#                 Bitbucket 101
#               </a>
# <a class="support-ga" data-support-gaq-page="GitTutorials" href="https://www.atlassian.com/git?utm_source=bitbucket&amp;utm_medium=link&amp;utm_campaign=help_dropdown&amp;utm_content=learn_git" target="_blank">
#                 Learn Git
#               </a>
# <a class="support-ga" data-support-gaq-page="DocumentationKB" href="https://confluence.atlassian.com/x/2w4zDQ" target="_blank">
#                 Knowledge base
#               </a>
# <a class="support-ga" data-support-gaq-page="Answers" href="https://answers.atlassian.com/tags/bitbucket/" target="_blank">
#                 Bitbucket on Atlassian Answers
#               </a>
# <a class="support-ga" data-support-gaq-page="Home" href="/support">
#               Support
#             </a>
# <a class="aui-dropdown2-trigger" href="#header-language" aria-controls="header-language" aria-owns="header-language" aria-haspopup="true" data-container="#header .aui-header-inner">
# <span>English</span></a>
# <a class="aui-dropdown2-radio interactive checked" data-value="en" href="#en">English</a>
# <a class="aui-dropdown2-radio interactive " data-value="ja" href="#ja">日本語</a>
# <a id="sign-up-link" class="aui-button aui-button-primary aui-style" href="/account/signup/">
#             Sign up
#           </a>
# <a href="/account/signin/?next=/repo/all%3Fname%3Dpython" class="aui-nav-link login-link">Log in</a>
# <a href="#" id="search-language-trigger">Choose...</a>
# <a class="avatar-link" href="/mshibly/python-examples-from-intro-to-python-course">
# <span class="repo-avatar-container size32" title="mshibly/Python examples from Intro to Python course">
# <img alt="mshibly/Python examples from Intro to Python course" src="https://d3oaxc4q5k2d6q.cloudfront.net/m/d3bf341c1e71/img/language-avatars/default_32.png" />
# </span>
# </a>
# /mshibly/python-examples-from-intro-to-python-course
# <a class="repo-link" href="/mshibly/python-examples-from-intro-to-python-course">mshibly / Python examples from Intro to Python course</a>
# /mshibly/python-examples-from-intro-to-python-course
# <a href="/mshibly/python-examples-from-intro-to-python-course/overview#followers">
#
#           20 watchers
#
#       </a>
# /mshibly/python-examples-from-intro-to-python-course/overview#followers
# <a class="avatar-link" href="/youbendroid/python-examples-from-intro-to-python-course">
# <span class="repo-avatar-container size32" title="youbendroid/Python examples from Intro to Python course">
# <img alt="youbendroid/Python examples from Intro to Python course" src="https://d3oaxc4q5k2d6q.cloudfront.net/m/d3bf341c1e71/img/language-avatars/default_32.png" />
# </span>
# </a>
# /youbendroid/python-examples-from-intro-to-python-course
# <a class="repo-link" href="/youbendroid/python-examples-from-intro-to-python-course">youbendroid / Python examples from Intro to Python course</a>
# /youbendroid/python-examples-from-intro-to-python-course
# <a href="/youbendroid/python-examples-from-intro-to-python-course/overview#followers">
#
#           1 watcher
#
#       </a>
# /youbendroid/python-examples-from-intro-to-python-course/overview#followers
# <a class="avatar-link" href="/bl4ckdu5t/python-examples-from-intro-to-python-course">
# <span class="repo-avatar-container size32" title="bl4ckdu5t/Python examples from Intro to Python course">
# <img alt="bl4ckdu5t/Python examples from Intro to Python course" src="https://d3oaxc4q5k2d6q.cloudfront.net/m/d3bf341c1e71/img/language-avatars/default_32.png" />
# </span>
# </a>
# /bl4ckdu5t/python-examples-from-intro-to-python-course
# <a class="repo-link" href="/bl4ckdu5t/python-examples-from-intro-to-python-course">bl4ckdu5t / Python examples from Intro to Python course</a>
# /bl4ckdu5t/python-examples-from-intro-to-python-course
# <a href="/bl4ckdu5t/python-examples-from-intro-to-python-course/overview#followers">
#
#           2 watchers
#
#       </a>
# /bl4ckdu5t/python-examples-from-intro-to-python-course/overview#followers
# <a class="avatar-link" href="/dasajitkumar/python-examples-from-intro-to-python-course">
# <span class="repo-avatar-container size32" title="dasajitkumar/python-examples-from-intro-to-python-course">
# <img alt="dasajitkumar/python-examples-from-intro-to-python-course" src="https://d3oaxc4q5k2d6q.cloudfront.net/m/d3bf341c1e71/img/language-avatars/default_32.png" />
# </span>
# </a>
# /dasajitkumar/python-examples-from-intro-to-python-course
# <a class="repo-link" href="/dasajitkumar/python-examples-from-intro-to-python-course">dasajitkumar / python-examples-from-intro-to-python-course</a>
# /dasajitkumar/python-examples-from-intro-to-python-course
# <a href="/dasajitkumar/python-examples-from-intro-to-python-course/overview#followers">
#
#           1 watcher
#
#       </a>
# /dasajitkumar/python-examples-from-intro-to-python-course/overview#followers
# <a class="avatar-link" href="/geespot/python-examples-from-intro-to-python-course">
# <span class="repo-avatar-container size32" title="geespot/Python examples from Intro to Python course">
# <img alt="geespot/Python examples from Intro to Python course" src="https://d3oaxc4q5k2d6q.cloudfront.net/m/d3bf341c1e71/img/language-avatars/default_32.png" />
# </span>
# </a>
# /geespot/python-examples-from-intro-to-python-course
# <a class="repo-link" href="/geespot/python-examples-from-intro-to-python-course">geespot / Python examples from Intro to Python course</a>
# /geespot/python-examples-from-intro-to-python-course
# <a href="/geespot/python-examples-from-intro-to-python-course/overview#followers">
#
#           1 watcher
#
#       </a>
# /geespot/python-examples-from-intro-to-python-course/overview#followers
# <a class="avatar-link" href="/alirezagh/python-examples-from-intro-to-python-course">
# <span class="repo-avatar-container size32" title="alirezagh/python-examples-from-intro-to-python-course">
# <img alt="alirezagh/python-examples-from-intro-to-python-course" src="https://d3oaxc4q5k2d6q.cloudfront.net/m/d3bf341c1e71/img/language-avatars/default_32.png" />
# </span>
# </a>
# /alirezagh/python-examples-from-intro-to-python-course
# <a class="repo-link" href="/alirezagh/python-examples-from-intro-to-python-course">alirezagh / python-examples-from-intro-to-python-course</a>
# /alirezagh/python-examples-from-intro-to-python-course
# <a href="/alirezagh/python-examples-from-intro-to-python-course/overview#followers">
#
#           0 watchers
#
#       </a>
# /alirezagh/python-examples-from-intro-to-python-course/overview#followers
# <a class="avatar-link" href="/cesardv/python-examples-from-intro-to-python-course">
# <span class="repo-avatar-container size32" title="cesardv/Python examples from Intro to Python course">
# <img alt="cesardv/Python examples from Intro to Python course" src="https://d3oaxc4q5k2d6q.cloudfront.net/m/d3bf341c1e71/img/language-avatars/default_32.png" />
# </span>
# </a>
# /cesardv/python-examples-from-intro-to-python-course
# <a class="repo-link" href="/cesardv/python-examples-from-intro-to-python-course">cesardv / Python examples from Intro to Python course</a>
# /cesardv/python-examples-from-intro-to-python-course
# <a href="/cesardv/python-examples-from-intro-to-python-course/overview#followers">
#
#           1 watcher
#
#       </a>
# /cesardv/python-examples-from-intro-to-python-course/overview#followers
# <a class="avatar-link" href="/liqixi_169/python-examples-from-intro-to-python-course">
# <span class="repo-avatar-container size32" title="liqixi_169/Python examples from Intro to Python course">
# <img alt="liqixi_169/Python examples from Intro to Python course" src="https://d3oaxc4q5k2d6q.cloudfront.net/m/d3bf341c1e71/img/language-avatars/default_32.png" />
# </span>
# </a>
# /liqixi_169/python-examples-from-intro-to-python-course
# <a class="repo-link" href="/liqixi_169/python-examples-from-intro-to-python-course">liqixi_169 / Python examples from Intro to Python course</a>
# /liqixi_169/python-examples-from-intro-to-python-course
# <a href="/liqixi_169/python-examples-from-intro-to-python-course/overview#followers">
#
#           1 watcher
#
#       </a>
# /liqixi_169/python-examples-from-intro-to-python-course/overview#followers
# <a class="avatar-link" href="/wangang/python-examples-from-intro-to-python-course">
# <span class="repo-avatar-container size32" title="wangang/Python examples from Intro to Python course">
# <img alt="wangang/Python examples from Intro to Python course" src="https://d3oaxc4q5k2d6q.cloudfront.net/m/d3bf341c1e71/img/language-avatars/default_32.png" />
# </span>
# </a>
# /wangang/python-examples-from-intro-to-python-course
# <a class="repo-link" href="/wangang/python-examples-from-intro-to-python-course">wangang / Python examples from Intro to Python course</a>
# /wangang/python-examples-from-intro-to-python-course
# <a href="/wangang/python-examples-from-intro-to-python-course/overview#followers">
#
#           1 watcher
#
#       </a>
# /wangang/python-examples-from-intro-to-python-course/overview#followers
# <a class="avatar-link" href="/Jing0/python-examples-from-intro-to-python-course">
# <span class="repo-avatar-container size32" title="Jing0/Python examples from Intro to Python course">
# <img alt="Jing0/Python examples from Intro to Python course" src="https://d3oaxc4q5k2d6q.cloudfront.net/m/d3bf341c1e71/img/language-avatars/default_32.png" />
# </span>
# </a>
# /Jing0/python-examples-from-intro-to-python-course
# <a class="repo-link" href="/Jing0/python-examples-from-intro-to-python-course">Jing0 / Python examples from Intro to Python course</a>
# /Jing0/python-examples-from-intro-to-python-course
# <a href="/Jing0/python-examples-from-intro-to-python-course/overview#followers">
#
#           1 watcher
#
#       </a>
# /Jing0/python-examples-from-intro-to-python-course/overview#followers
# <a href="#" aria-disabled="true">Prev</a>
# <a href="/repo/all/2?name=python">2</a>
# <a href="/repo/all/3?name=python">3</a>
# <a href="/repo/all/4?name=python">4</a>
# <a href="/repo/all/5?name=python">5</a>
# <a href="/repo/all/1060?name=python">1060</a>
# <a href="/repo/all/2?name=python">Next</a>
# <a href="https://confluence.atlassian.com/x/cgozDQ" target="_blank" class="help-link documentation">
# <strong>Documentation</strong>
#     All the information you need to get started.
#   </a>
# <a href="https://confluence.atlassian.com/x/bJgXE" target="_blank" class="help-link forking">
# <strong>Forking &amp; pulling</strong>
#     Let's go over the basics of repository management.
#   </a>
# <a href="https://confluence.atlassian.com/x/IYBGDQ" target="_blank" class="help-link api">
# <strong>API</strong>
#     Bitbucket has an extensive API. Check it out!
#   </a>
# <a class="support-ga" target="_blank" data-support-gaq-page="Blog" href="http://blog.bitbucket.org">Blog</a>
# <a class="support-ga" target="_blank" data-support-gaq-page="Home" href="/support">Support</a>
# <a class="support-ga" data-support-gaq-page="PlansPricing" href="/plans">Plans &amp; pricing</a>
# <a class="support-ga" target="_blank" data-support-gaq-page="DocumentationHome" href="//confluence.atlassian.com/display/BITBUCKET">Documentation</a>
# <a class="support-ga" target="_blank" data-support-gaq-page="DocumentationAPI" href="//confluence.atlassian.com/x/IYBGDQ">API</a>
# <a class="support-ga" target="_blank" data-support-gaq-page="SiteStatus" href="http://status.bitbucket.org/">Server status</a>
# <a class="support-ga" id="meta-info" data-support-gaq-page="MetaInfo" href="#">Version info</a>
# <a class="support-ga" target="_blank" data-support-gaq-page="EndUserAgreement" href="//www.atlassian.com/end-user-agreement?utm_source=bitbucket&amp;utm_medium=link&amp;utm_campaign=footer">Terms of service</a>
# <a class="support-ga" target="_blank" data-support-gaq-page="PrivacyPolicy" href="//www.atlassian.com/company/privacy?utm_source=bitbucket&amp;utm_medium=link&amp;utm_campaign=footer">Privacy policy</a>
# <a class="support-ga" target="_blank" data-support-gaq-page="GitDocumentation" href="http://git-scm.com/">Git 1.8.5.2</a>
# <a class="support-ga" target="_blank" data-support-gaq-page="HgDocumentation" href="http://mercurial.selenic.com/">Mercurial 2.9</a>
# <a class="support-ga" target="_blank" data-support-gaq-page="DjangoDocumentation" href="https://www.djangoproject.com/">Django 1.6.5</a>
# <a class="support-ga" target="_blank" data-support-gaq-page="PythonDocumentation" href="http://www.python.org/">Python 2.7.3</a>
# <a class="support-ga" target="_blank" data-support-gaq-page="DeployedVersion" href="#">d3bf341c1e71 / d3bf341c1e71 @ app19</a>
# <a id="atlassian-jira-link" target="_blank" title="Track everything – bugs, tasks, deadlines, code – and pull reports to stay informed." href="http://www.atlassian.com/software/jira?utm_source=bitbucket&amp;utm_medium=link&amp;utm_campaign=bitbucket_footer">JIRA</a>
# <a id="atlassian-confluence-link" target="_blank" title="Content Creation, Collaboration &amp; Knowledge Sharing for Teams." href="http://www.atlassian.com/software/confluence/overview/team-collaboration-software?utm_source=bitbucket&amp;utm_medium=link&amp;utm_campaign=bitbucket_footer">Confluence</a>
# <a id="atlassian-bamboo-link" target="_blank" title="Continuous integration and deployment, release management." href="http://www.atlassian.com/software/bamboo/overview?utm_source=bitbucket&amp;utm_medium=link&amp;utm_campaign=bitbucket_footer">Bamboo</a>
# <a id="atlassian-stash-link" target="_blank" title="Git repo management, behind your firewall and Enterprise-ready." href="http://www.atlassian.com/software/stash?utm_source=bitbucket&amp;utm_medium=link&amp;utm_campaign=bitbucket_footer">Stash</a>
# <a id="atlassian-sourcetree-link" target="_blank" title="A free Git and Mercurial desktop client for Mac or Windows." href="http://www.sourcetreeapp.com/?utm_source=bitbucket&amp;utm_medium=link&amp;utm_campaign=bitbucket_footer">SourceTree</a>
# <a id="atlassian-hipchat-link" target="_blank" title="Group chat and IM built for teams." href="http://www.hipchat.com/?utm_source=bitbucket&amp;utm_medium=link&amp;utm_campaign=bitbucket_footer">HipChat</a>
# <a target="_blank" title="Bitbucket is developed by Atlassian in San Francisco." href="http://www.atlassian.com?utm_source=bitbucket&amp;utm_medium=logo&amp;utm_campaign=bitbucket_footer">Atlassian</a>

# %% [markdown]
# ## Task 1A: Retrieve and store links from all pages

# %% [markdown]
# ## Task 1B: Try several keywords, what keywords yield the largest number of repositories?

# %% [markdown]
# ## Example 2. Search for 'site:bitbucket.org' via google.

# %%
import requests, json, sys, time, re, BeautifulSoup
URL = 'https://www.google.com/search?q=site%3Abitbucket.org'
r = requests .get(URL)
t = r.text
soup = BeautifulSoup.BeautifulSoup(t)
start = 0
npages = 8
for link in soup.findAll('a'):
    s = link.get('href')
    m = re.search(r'https://bitbucket.org/([^&%]*)', s)
    if m:
        print m.group(1)    
#now need to go over the remaining pages from google search
# https://www.google.com/search?q=site%3Abitbucket.org&start=900
# until
# Out:
# cmorris
# cmorris
# cmorris
# ddevine
# ddevine
# durin42
# durin42
# durin42
# ralphbean
# ralphbean
# klorenz
# klorenz
# nvdaaddonteam
# nvdaaddonteam
# nvdaaddonteam
# eaganj
# eaganj
# techtonik
# techtonik
# techtonik
# chapmanb/
# chapmanb/
# chapmanb/

# %% [markdown]
# ## Task 2A: Retrieve repository links over all pages returned by google search

# %% [markdown]
# # Merge all the lists obtained so far
