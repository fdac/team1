# %% [markdown]
# #Project 1: Discover BitBucket code repositories
#
# ## Context
# You work for a cloud application provider DeveloperParadise that needs to convince its investors
# that their business has a bright future.
#
# Your task is to show that the number of customers (users of DeveloperParadise, which happens to
# compete with Atlassian's BitBucket) is comparable to that of  BitBucket. The presentation for investors
# is next week (completely incidentally, exactly on the day this project is due).
#
# Feel free to use examples below or any other information you can gather to obtain as complete as possible list of
# users and repositories hosted on BitBucket.
#
# While a template for the search strategy is provided, feel free to use any means (including borrowing with attribution from the other teams) to get as many as you can within this very short but, unfortunately, very realistic time frame.
#
#
# ## Important Notes
#
# Please keep in mind operational data pitfalls, such as
#    * lack of context
#    * missing data
#    * possibly incorrect data
#
# 1. DeveloperParadise may focus on specific types of customers (e.g., size, programming language, or other characteristics), and that number is a subset of all customers.
#  * Pick the desired characteristics of target customers for DeveloperParadise and estimate their percentage is in your retrieved set
# 1. Is there any way to estimate what fraction of all BitBucket customers/repositories are in the retrieved set?
# 1. Is the distribution of different types of customers the same in the retrieved and undiscovered sets of BitBucket customers?

# %% [markdown]
# ### Example 1. Search for a keyword 'test'
#
# * Unfortunately, BitBucket does not have a documented search API
#
# So feel free to experiment with an undocumented search API below that appears to
# yeld some results, though it is not clear how complete they are and
# how exactly the results are provided by BitBucket.  You don't need to
# follow the search strategy outlined below, it is just one of many possible approaches.

# %%
import requests, json, sys, time, re, BeautifulSoup
key = 'python'
URL = 'https://bitbucket.org/repo/all?name=' + key
r = requests .get(URL)
t = r.text
soup = BeautifulSoup.BeautifulSoup(t)
start = 0
npages = 1
for link in soup.findAll('a'):
    if (start == 3): continue
    s = link.get('href')
    if (start == 0):
        if ('/account/signin/?next' in s):
            start = 1
            continue
        else:
            continue   
    if  s == '#': continue 
        
    # This is the way the remaining pages in the search results are marked
    m = re.search(r'^/repo/all/(\d*)\?', s)
    if  m:
        start = 2
        #get max num
        i = m.group(1)
        if (int(i) > npages): npages = int(i)
        #print npages
    else:
        if start == 2: 
            start = 3
            continue
        # Print the repo urls
        print s
        
#now need to go over the remaining pages        
# from 2 to npages
#np = unicode(npages)
#print '/repo/all/'+ np + '?name=' + key
# Out:
# /mshibly/python-examples-from-intro-to-python-course
# /mshibly/python-examples-from-intro-to-python-course
# /mshibly/python-examples-from-intro-to-python-course/overview#followers
# /Mike_5335/python-examples-from-intro-to-python-course
# /Mike_5335/python-examples-from-intro-to-python-course
# /Mike_5335/python-examples-from-intro-to-python-course/overview#followers
# /4nth0nyx/python-examples-from-intro-to-python-course
# /4nth0nyx/python-examples-from-intro-to-python-course
# /4nth0nyx/python-examples-from-intro-to-python-course/overview#followers
# /dasajitkumar/python-examples-from-intro-to-python-course
# /dasajitkumar/python-examples-from-intro-to-python-course
# /dasajitkumar/python-examples-from-intro-to-python-course/overview#followers
# /geespot/python-examples-from-intro-to-python-course
# /geespot/python-examples-from-intro-to-python-course
# /geespot/python-examples-from-intro-to-python-course/overview#followers
# /vuthanhlqdtu/python-examples-from-intro-to-python-course
# /vuthanhlqdtu/python-examples-from-intro-to-python-course
# /vuthanhlqdtu/python-examples-from-intro-to-python-course/overview#followers
# /alirezagh/python-examples-from-intro-to-python-course
# /alirezagh/python-examples-from-intro-to-python-course
# /alirezagh/python-examples-from-intro-to-python-course/overview#followers
# /raidyue/python-examples-from-intro-to-python-course
# /raidyue/python-examples-from-intro-to-python-course
# /raidyue/python-examples-from-intro-to-python-course/overview#followers
# /pablo_lopes/python-examples-from-intro-to-python-course
# /pablo_lopes/python-examples-from-intro-to-python-course
# /pablo_lopes/python-examples-from-intro-to-python-course/overview#followers
# /liqixi_169/python-examples-from-intro-to-python-course
# /liqixi_169/python-examples-from-intro-to-python-course
# /liqixi_169/python-examples-from-intro-to-python-course/overview#followers

# %% [markdown]
# ## Task 1A: Retrieve and store links from all pages

# %% [markdown]
# ## Task 1B: Try several keywords, what keywords yield the largest number of repositories?

# %% [markdown]
# ## Example 2. Search for 'site:bitbucket.org' via google.

# %%
import requests, json, sys, time, re, BeautifulSoup
URL = 'https://www.google.com/search?q=site%3Abitbucket.org'
r = requests .get(URL)
t = r.text
soup = BeautifulSoup.BeautifulSoup(t)
start = 0
npages = 1
for link in soup.findAll('a'):
    s = link.get('href')
    m = re.search(r'https://bitbucket.org/([^&%]*)', s)
    if m:
        print m.group(1)    
#now need to go over the remaining pages from google search
# https://www.google.com/search?q=site%3Abitbucket.org&start=900
# until
# Out:
# cmorris
# cmorris
# cmorris
# ralphbean
# ralphbean
# jendrikseipp
# jendrikseipp
# klorenz
# klorenz
# nvdaaddonteam
# nvdaaddonteam
# nvdaaddonteam
# eaganj
# eaganj
# techtonik
# techtonik
# techtonik
# chapmanb/
# chapmanb/
# chapmanb/
# iElectric
# iElectric
# iElectric

# %%
import requests, json, sys, time, re, BeautifulSoup
users_list = []
users_no_dup = []
npages = 100
print "hello work"
for start in range(0,10):
    URL = 'https://www.google.com/search?q=site%3Abitbucket.org&start=' + str(start)
    r = requests .get(URL)
    t = r.text
    soup = BeautifulSoup.BeautifulSoup(t)
    npages = 1
    for link in soup.findAll('a'):
        s = link.get('href')
        m = re.search(r'https://bitbucket.org/([^&%]*)', s)
        if m:
            users_list.append(m.group(1))
            print m.group(1)
            

for users in users_list:
    print users
    if users not in users_no_dup:
        users_no_dup.append(users)

#print "Total number of Users found in 100 pages", len(users_no_dup)

for out in users_no_dup:
    print out


#now need to go over the remaining pages from google search
# https://www.google.com/search?q=site%3Abitbucket.org&start=900
# until
# Out:
# hello work
# malb
# malb
# malb
# cmorris
# cmorris
# cmorris
# ralphbean
# ralphbean
# klorenz
# klorenz
# nvdaaddonteam
# nvdaaddonteam
# nvdaaddonteam
# rileytestut
# rileytestut
# eaganj
# eaganj
# techtonik
# techtonik
# techtonik
# chapmanb/
# chapmanb/
# chapmanb/
# malb
# malb
# malb
# cmorris
# cmorris
# cmorris
# ralphbean
# ralphbean
# klorenz
# klorenz
# nvdaaddonteam
# nvdaaddonteam
# nvdaaddonteam
# rileytestut
# rileytestut
# eaganj
# eaganj
# techtonik
# techtonik
# techtonik
# chapmanb/
# chapmanb/
# chapmanb/
# iElectric
# iElectric
# iElectric
# cmorris
# cmorris
# cmorris
# ralphbean
# ralphbean
# klorenz
# klorenz
# nvdaaddonteam
# nvdaaddonteam
# nvdaaddonteam
# rileytestut
# rileytestut
# eaganj
# eaganj
# techtonik
# techtonik
# techtonik
# chapmanb/
# chapmanb/
# chapmanb/
# iElectric
# iElectric
# iElectric
# petebunting
# petebunting
# petebunting
# ralphbean
# ralphbean
# klorenz
# klorenz
# nvdaaddonteam
# nvdaaddonteam
# nvdaaddonteam
# rileytestut
# rileytestut
# eaganj
# eaganj
# techtonik
# techtonik
# techtonik
# chapmanb/
# chapmanb/
# chapmanb/
# iElectric
# iElectric
# iElectric
# petebunting
# petebunting
# petebunting
# tunnuz
# tunnuz
# tunnuz
# klorenz
# klorenz
# nvdaaddonteam
# nvdaaddonteam
# nvdaaddonteam
# rileytestut
# rileytestut
# eaganj
# eaganj
# techtonik
# techtonik
# techtonik
# chapmanb/
# chapmanb/
# chapmanb/
# iElectric
# iElectric
# iElectric
# petebunting
# petebunting
# petebunting
# tunnuz
# tunnuz
# tunnuz
# piotrkarbowski
# piotrkarbowski
# piotrkarbowski
# nvdaaddonteam
# nvdaaddonteam
# nvdaaddonteam
# rileytestut
# rileytestut
# eaganj
# eaganj
# techtonik
# techtonik
# techtonik
# chapmanb/
# chapmanb/
# chapmanb/
# iElectric
# iElectric
# iElectric
# petebunting
# petebunting
# petebunting
# tunnuz
# tunnuz
# tunnuz
# piotrkarbowski
# piotrkarbowski
# piotrkarbowski
# godane
# godane
# godane
# rileytestut
# rileytestut
# eaganj
# eaganj
# techtonik
# techtonik
# techtonik
# chapmanb/
# chapmanb/
# chapmanb/
# iElectric
# iElectric
# iElectric
# petebunting
# petebunting
# petebunting
# tunnuz
# tunnuz
# tunnuz
# piotrkarbowski
# piotrkarbowski
# piotrkarbowski
# godane
# godane
# godane
# fbennett
# fbennett
# fbennett
# eaganj
# eaganj
# techtonik
# techtonik
# techtonik
# chapmanb/
# chapmanb/
# chapmanb/
# iElectric
# iElectric
# iElectric
# petebunting
# petebunting
# petebunting
# tunnuz
# tunnuz
# tunnuz
# piotrkarbowski
# piotrkarbowski
# piotrkarbowski
# godane
# godane
# godane
# fbennett
# fbennett
# fbennett
# silentium
# silentium
# techtonik
# techtonik
# techtonik
# chapmanb/
# chapmanb/
# chapmanb/
# iElectric
# iElectric
# iElectric
# petebunting
# petebunting
# petebunting
# tunnuz
# tunnuz
# tunnuz
# piotrkarbowski
# piotrkarbowski
# piotrkarbowski
# godane
# godane
# godane
# fbennett
# fbennett
# fbennett
# silentium
# silentium
# chapmanb/
# chapmanb/
# chapmanb/
# iElectric
# iElectric
# iElectric
# petebunting
# petebunting
# petebunting
# tunnuz
# tunnuz
# tunnuz
# piotrkarbowski
# piotrkarbowski
# piotrkarbowski
# godane
# godane
# godane
# fbennett
# fbennett
# fbennett
# silentium
# silentium
# slime73
# slime73
# slime73
#
#
#
# malb
# malb
# malb
# cmorris
# cmorris
# cmorris
# ralphbean
# ralphbean
# klorenz
# klorenz
# nvdaaddonteam
# nvdaaddonteam
# nvdaaddonteam
# rileytestut
# rileytestut
# eaganj
# eaganj
# techtonik
# techtonik
# techtonik
# chapmanb/
# chapmanb/
# chapmanb/
# malb
# malb
# malb
# cmorris
# cmorris
# cmorris
# ralphbean
# ralphbean
# klorenz
# klorenz
# nvdaaddonteam
# nvdaaddonteam
# nvdaaddonteam
# rileytestut
# rileytestut
# eaganj
# eaganj
# techtonik
# techtonik
# techtonik
# chapmanb/
# chapmanb/
# chapmanb/
# iElectric
# iElectric
# iElectric
# cmorris
# cmorris
# cmorris
# ralphbean
# ralphbean
# klorenz
# klorenz
# nvdaaddonteam
# nvdaaddonteam
# nvdaaddonteam
# rileytestut
# rileytestut
# eaganj
# eaganj
# techtonik
# techtonik
# techtonik
# chapmanb/
# chapmanb/
# chapmanb/
# iElectric
# iElectric
# iElectric
# petebunting
# petebunting
# petebunting
# ralphbean
# ralphbean
# klorenz
# klorenz
# nvdaaddonteam
# nvdaaddonteam
# nvdaaddonteam
# rileytestut
# rileytestut
# eaganj
# eaganj
# techtonik
# techtonik
# techtonik
# chapmanb/
# chapmanb/
# chapmanb/
# iElectric
# iElectric
# iElectric
# petebunting
# petebunting
# petebunting
# tunnuz
# tunnuz
# tunnuz
# klorenz
# klorenz
# nvdaaddonteam
# nvdaaddonteam
# nvdaaddonteam
# rileytestut
# rileytestut
# eaganj
# eaganj
# techtonik
# techtonik
# techtonik
# chapmanb/
# chapmanb/
# chapmanb/
# iElectric
# iElectric
# iElectric
# petebunting
# petebunting
# petebunting
# tunnuz
# tunnuz
# tunnuz
# piotrkarbowski
# piotrkarbowski
# piotrkarbowski
# nvdaaddonteam
# nvdaaddonteam
# nvdaaddonteam
# rileytestut
# rileytestut
# eaganj
# eaganj
# techtonik
# techtonik
# techtonik
# chapmanb/
# chapmanb/
# chapmanb/
# iElectric
# iElectric
# iElectric
# petebunting
# petebunting
# petebunting
# tunnuz
# tunnuz
# tunnuz
# piotrkarbowski
# piotrkarbowski
# piotrkarbowski
# godane
# godane
# godane
# rileytestut
# rileytestut
# eaganj
# eaganj
# techtonik
# techtonik
# techtonik
# chapmanb/
# chapmanb/
# chapmanb/
# iElectric
# iElectric
# iElectric
# petebunting
# petebunting
# petebunting
# tunnuz
# tunnuz
# tunnuz
# piotrkarbowski
# piotrkarbowski
# piotrkarbowski
# godane
# godane
# godane
# fbennett
# fbennett
# fbennett
# eaganj
# eaganj
# techtonik
# techtonik
# techtonik
# chapmanb/
# chapmanb/
# chapmanb/
# iElectric
# iElectric
# iElectric
# petebunting
# petebunting
# petebunting
# tunnuz
# tunnuz
# tunnuz
# piotrkarbowski
# piotrkarbowski
# piotrkarbowski
# godane
# godane
# godane
# fbennett
# fbennett
# fbennett
# silentium
# silentium
# techtonik
# techtonik
# techtonik
# chapmanb/
# chapmanb/
# chapmanb/
# iElectric
# iElectric
# iElectric
# petebunting
# petebunting
# petebunting
# tunnuz
# tunnuz
# tunnuz
# piotrkarbowski
# piotrkarbowski
# piotrkarbowski
# godane
# godane
# godane
# fbennett
# fbennett
# fbennett
# silentium
# silentium
# chapmanb/
# chapmanb/
# chapmanb/
# iElectric
# iElectric
# iElectric
# petebunting
# petebunting
# petebunting
# tunnuz
# tunnuz
# tunnuz
# piotrkarbowski
# piotrkarbowski
# piotrkarbowski
# godane
# godane
# godane
# fbennett
# fbennett
# fbennett
# silentium
# silentium
# slime73
# slime73
# slime73
#
# malb
# cmorris
# ralphbean
# klorenz
# nvdaaddonteam
# rileytestut
# eaganj
# techtonik
# chapmanb/
# iElectric
# petebunting
# tunnuz
# piotrkarbowski
# godane
# fbennett
# silentium
# slime73

# %% [markdown]
# ## Task 2A: Retrieve repository links over all pages returned by google search

# %%
1) Get all users (filter all user)
2) Get all repos (Language, size)
    a) Try and create groups based upon the parameters that we got above.
    b) 
3) Get all repos (based on keywords)
4)

# %% [markdown]
# # Merge all the lists obtained so far

# %%
#modify DLR
import requests, json, sys, time, re, BeautifulSoup
users_list = []
users_python=[]
users_no_dup = []
#npages = 100
print "Start search..."
for start in range(0,90,10):
    URL = 'https://www.google.com/search?q=site%3Abitbucket.org&start=' + str(start)
    r = requests .get(URL)
    t = r.text
    soup = BeautifulSoup.BeautifulSoup(t)
    #npages = 1
    for link in soup.findAll('a'):
        s = link.get('href')
        m = re.search(r'https://bitbucket.org/([^&%/]*)', s)
        if m:
            users_list.append(m.group(1))
            #print m.group(1)

#Remove duplicates into 'users_no_dup'    
for users in users_list:
 #   print users
    if users not in users_no_dup:
        users_no_dup.append(users)

#Print unique results from search
print "Total number of Users found in 100 pages", len(users_no_dup)
#for out in users_no_dup:
#   print out

print "List of Python users:"
for user in users_no_dup:
    URL2 = 'https://bitbucket.org/'+ user +'/profile/repositories?language=python'
    rr = requests.get(URL2)
    tt = rr.text
    mm = re.search(r'Nothing to see here', tt)
    if not mm:
        #print user
    #else:
        #print user # + 'YES'
        users_python.append(user)

    
print "Total number of Python users found in 100 pages", len(users_python)
for out2 in users_python:
    print out2
    
    
    
#now need to go over the remaining pages from google search
# https://www.google.com/search?q=site%3Abitbucket.org&start=900
# until
# Out:
# Start search...
# ---------------------------------------------------------------------------
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-2-b9272b8a021d> in <module>()
#       8 for start in range(0,90,10):
#       9     URL = 'https://www.google.com/search?q=site%3Abitbucket.org&start=' + str(start)
# ---> 10     r = requests .get(URL)
#      11     t = r.text
#      12     soup = BeautifulSoup.BeautifulSoup(t)
#
# /usr/lib/python2.7/dist-packages/requests/api.pyc in get(url, **kwargs)
#      53
#      54     kwargs.setdefault('allow_redirects', True)
# ---> 55     return request('get', url, **kwargs)
#      56
#      57
#
# /usr/lib/python2.7/dist-packages/requests/api.pyc in request(method, url, **kwargs)
#      42
#      43     session = sessions.Session()
# ---> 44     return session.request(method=method, url=url, **kwargs)
#      45
#      46
#
# /usr/lib/python2.7/dist-packages/requests/sessions.pyc in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert)
#     381             'allow_redirects': allow_redirects,
#     382         }
# --> 383         resp = self.send(prep, **send_kwargs)
#     384
#     385         return resp
#
# /usr/lib/python2.7/dist-packages/requests/sessions.pyc in send(self, request, **kwargs)
#     484         start = datetime.utcnow()
#     485         # Send the request
# --> 486         r = adapter.send(request, **kwargs)
#     487         # Total elapsed time of the request (approximately)
#     488         r.elapsed = datetime.utcnow() - start
#
# /usr/lib/python2.7/dist-packages/requests/adapters.pyc in send(self, request, stream, timeout, verify, cert, proxies)
#     376
#     377         except MaxRetryError as e:
# --> 378             raise ConnectionError(e)
#     379
#     380         except _ProxyError as e:
#
# ConnectionError: HTTPSConnectionPool(host='www.google.com', port=443): Max retries exceeded with url: /search?q=site%3Abitbucket.org&start=40 (Caused by <class 'socket.gaierror'>: [Errno -2] Name or service not known)

# %%
# Out:
# [0, 2, 4, 6, 8]
